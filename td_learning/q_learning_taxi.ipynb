# %%
import random
import gym
from IPython import display
import time
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
env = gym.make('Taxi-v2')

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : : : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
Q = {}
for s in range(env.observation_space.n):
    for a in range(env.action_space.n):
        Q[(s,a)] = 0.0

# %%
def update_q_table(prev_state, action, reward, next_state, alpha, gamme):
    qa = max([Q[(nextstate,a)] for a in range(env.action_space.n)])
    Q[(prev_state, action)] += alpha * (reward + gamma * qa - Q[(prev_state, action)])

# %%
def epsilon_greedy(state, epsilon):
    if random.uniform(0,1) < epsilon:
        return env.action_space.sample()
    else:
        return max(list(range(env.action_space.n)), key = lambda x: Q[(state,x)])

# %%
alpha = 0.7
gamma = 0.999
epsilon = 0.3

# %%
for i in range(400):
    r = 0
    state = env.reset()
    
    while True:
        action = epsilon_greedy(state, epsilon)
        nextstate, reward, done, _ = env.step(action)
        
        update_q_table(state, action, reward, nextstate, alpha, gamma)
        
        state = nextstate
        r += reward
        
        if done:
            break
    print("total reward: ", r)

env.close()
# Out:
# total reward:  -515
# total reward:  -605
# total reward:  -614
# total reward:  -605
# total reward:  -503
# total reward:  -416
# total reward:  -461
# total reward:  -524
# total reward:  -497
# total reward:  -98
# total reward:  -524
# total reward:  -389
# total reward:  -524
# total reward:  -389
# total reward:  -506
# total reward:  -317
# total reward:  -407
# total reward:  -515
# total reward:  -434
# total reward:  -641
# total reward:  -605
# total reward:  -425
# total reward:  -497
# total reward:  -136
# total reward:  -632
# total reward:  -506
# total reward:  -605
# total reward:  -353
# total reward:  -82
# total reward:  -551
# total reward:  -371
# total reward:  -461
# total reward:  -110
# total reward:  -59
# total reward:  -290
# total reward:  -345
# total reward:  -63
# total reward:  -102
# total reward:  -77
# total reward:  -102
# total reward:  -247
# total reward:  -229
# total reward:  -269
# total reward:  -587
# total reward:  -353
# total reward:  -158
# total reward:  -273
# total reward:  -303
# total reward:  -431
# total reward:  -215
# total reward:  -461
# total reward:  -152
# total reward:  -272
# total reward:  -130
# total reward:  -452
# total reward:  -110
# total reward:  -211
# total reward:  -452
# total reward:  -16
# total reward:  -41
# total reward:  -389
# total reward:  -362
# total reward:  -389
# total reward:  -425
# total reward:  -398
# total reward:  -113
# total reward:  -116
# total reward:  11
# total reward:  -149
# total reward:  -70
# total reward:  -33
# total reward:  -138
# total reward:  -2
# total reward:  -225
# total reward:  -61
# total reward:  -398
# total reward:  -47
# total reward:  -45
# total reward:  -352
# total reward:  -425
# total reward:  -226
# total reward:  -416
# total reward:  -126
# total reward:  -443
# total reward:  -6
# total reward:  -398
# total reward:  -96
# total reward:  -94
# total reward:  -165
# total reward:  -156
# total reward:  -332
# total reward:  -244
# total reward:  -141
# total reward:  -16
# total reward:  -54
# total reward:  -152
# total reward:  -6
# total reward:  -228
# total reward:  -355
# total reward:  -72
# total reward:  -80
# total reward:  -125
# total reward:  4
# total reward:  12
# total reward:  -3
# total reward:  -119
# total reward:  -274
# total reward:  -41
# total reward:  -348
# total reward:  -91
# total reward:  -88
# total reward:  -7
# total reward:  -93
# total reward:  -300
# total reward:  9
# total reward:  -52
# total reward:  -16
# total reward:  -132
# total reward:  -32
# total reward:  -21
# total reward:  -88
# total reward:  -39
# total reward:  -12
# total reward:  -157
# total reward:  -21
# total reward:  -67
# total reward:  -58
# total reward:  -106
# total reward:  -85
# total reward:  -275
# total reward:  -296
# total reward:  -22
# total reward:  -204
# total reward:  -249
# total reward:  12
# total reward:  -34
# total reward:  -82
# total reward:  -89
# total reward:  -49
# total reward:  -144
# total reward:  5
# total reward:  -237
# total reward:  -147
# total reward:  -129
# total reward:  -9
# total reward:  -43
# total reward:  -231
# total reward:  -61
# total reward:  -61
# total reward:  -202
# total reward:  8
# total reward:  -49
# total reward:  -27
# total reward:  12
# total reward:  -55
# total reward:  -180
# total reward:  -36
# total reward:  -15
# total reward:  -13
# total reward:  -36
# total reward:  -20
# total reward:  -55
# total reward:  -41
# total reward:  -24
# total reward:  8
# total reward:  -25
# total reward:  -7
# total reward:  -84
# total reward:  -112
# total reward:  3
# total reward:  -6
# total reward:  1
# total reward:  -250
# total reward:  -14
# total reward:  -21
# total reward:  -294
# total reward:  -206
# total reward:  -8
# total reward:  -59
# total reward:  -86
# total reward:  -40
# total reward:  -253
# total reward:  -36
# total reward:  -139
# total reward:  -42
# total reward:  -26
# total reward:  -126
# total reward:  -94
# total reward:  -211
# total reward:  -41
# total reward:  -35
# total reward:  -69
# total reward:  -53
# total reward:  1
# total reward:  -17
# total reward:  -33
# total reward:  -87
# total reward:  -3
# total reward:  -3
# total reward:  -26
# total reward:  12
# total reward:  -1
# total reward:  7
# total reward:  -15
# total reward:  -6
# total reward:  -85
# total reward:  -70
# total reward:  -13
# total reward:  -31
# total reward:  -3
# total reward:  -15
# total reward:  -92
# total reward:  -46
# total reward:  -12
# total reward:  -17
# total reward:  -77
# total reward:  -57
# total reward:  7
# total reward:  -1
# total reward:  -12
# total reward:  -82
# total reward:  -26
# total reward:  3
# total reward:  -53
# total reward:  -72
# total reward:  -9
# total reward:  -8
# total reward:  -68
# total reward:  -40
# total reward:  -21
# total reward:  -14
# total reward:  -45
# total reward:  -44
# total reward:  -69
# total reward:  1
# total reward:  -34
# total reward:  -101
# total reward:  12
# total reward:  -122
# total reward:  -5
# total reward:  -23
# total reward:  -57
# total reward:  -6
# total reward:  -8
# total reward:  7
# total reward:  -3
# total reward:  -23
# total reward:  -14
# total reward:  -26
# total reward:  -50
# total reward:  -22
# total reward:  -10
# total reward:  -319
# total reward:  -123
# total reward:  -34
# total reward:  -41
# total reward:  -3
# total reward:  -22
# total reward:  -41
# total reward:  5
# total reward:  -39
# total reward:  -4
# total reward:  -17
# total reward:  -23
# total reward:  -58
# total reward:  -13
# total reward:  -18
# total reward:  -29
# total reward:  -24
# total reward:  2
# total reward:  -2
# total reward:  -51
# total reward:  6
# total reward:  -7
# total reward:  -23
# total reward:  -103
# total reward:  -13
# total reward:  -3
# total reward:  -95
# total reward:  -25
# total reward:  -2
# total reward:  -33
# total reward:  -15
# total reward:  -50
# total reward:  -28
# total reward:  -18
# total reward:  8
# total reward:  -39
# total reward:  -18
# total reward:  -4
# total reward:  -74
# total reward:  -31
# total reward:  -53
# total reward:  -39
# total reward:  -42
# total reward:  -26
# total reward:  -16
# total reward:  -16
# total reward:  -32
# total reward:  -2
# total reward:  4
# total reward:  -6
# total reward:  -15
# total reward:  -22
# total reward:  -14
# total reward:  -51
# total reward:  -15
# total reward:  -38
# total reward:  -19
# total reward:  2
# total reward:  -23
# total reward:  -17
# total reward:  -20
# total reward:  -3
# total reward:  -6
# total reward:  4
# total reward:  6
# total reward:  9
# total reward:  -2
# total reward:  3
# total reward:  -4
# total reward:  4
# total reward:  0
# total reward:  -40
# total reward:  -24
# total reward:  -6
# total reward:  -7
# total reward:  9
# total reward:  -51
# total reward:  -11
# total reward:  -6
# total reward:  -21
# total reward:  -1
# total reward:  -11
# total reward:  -6
# total reward:  -39
# total reward:  8
# total reward:  -38
# total reward:  7
# total reward:  -27
# total reward:  -36
# total reward:  -10
# total reward:  -44
# total reward:  -8
# total reward:  -3
# total reward:  -5
# total reward:  -10
# total reward:  -21
# total reward:  -4
# total reward:  -15
# total reward:  8
# total reward:  -41
# total reward:  3
# total reward:  11
# total reward:  -11
# total reward:  -21
# total reward:  -31
# total reward:  1
# total reward:  -18
# total reward:  -11
# total reward:  -13
# total reward:  -15
# total reward:  -20
# total reward:  12
# total reward:  2
# total reward:  -50
# total reward:  -60
# total reward:  9
# total reward:  4
# total reward:  2
# total reward:  12
# total reward:  -3
# total reward:  -12
# total reward:  10
# total reward:  -80
# total reward:  -11
# total reward:  -2
# total reward:  -18
# total reward:  -45
# total reward:  -16
# total reward:  -31
# total reward:  -6
# total reward:  -5
# total reward:  -6
# total reward:  -20
# total reward:  -27
# total reward:  9
# total reward:  -8
# total reward:  -15
# total reward:  9
# total reward:  7
# total reward:  -34
# total reward:  -29
# total reward:  -68
# total reward:  -21
# total reward:  -10
# total reward:  -6
# total reward:  -7
# total reward:  -10
# total reward:  -16

# %%
state = env.reset()
total_reward = 0

while True:
    action = max(list(range(env.action_space.n)), key = lambda x: Q[(state, x)])
    display.clear_output(wait=True)
    display.display(plt.gcf())
    env.render()
    
    state, reward, done, _ = env.step(action)
    total_reward += reward
    print('Epidode Reward=', total_reward)
    time.sleep(0.5)
    
    if done:
        break

env.close()
